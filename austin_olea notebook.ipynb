# %% [markdown]
# # Florida

# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
file_path = ('zhvi_data.csv')

data = pd.read_csv(file_path)

data.head()
# Out:
#            RegionName RegionType State                             Metro  \
# 0  Los Angeles County     County    CA    Los Angeles-Long Beach-Anaheim
# 1         Cook County     County    IL          Chicago-Naperville-Elgin
# 2       Harris County     County    TX  Houston-The Woodlands-Sugar Land
# 3     Maricopa County     County    AZ           Phoenix-Mesa-Scottsdale
# 4    San Diego County     County    CA                San Diego-Carlsbad
#
#    StateCodeFIPS  MunicipalCodeFIPS  2017-01-31  2017-02-28  2017-03-31  \
# 0              6                 37    567167.0    570020.0    573344.0
# 1             17                 31    235165.0    235814.0    237493.0
# 2             48                201    177989.0    178366.0    178869.0
# 3              4                 13    242028.0    243189.0    244568.0
# 4              6                 73    528758.0    531624.0    536251.0
#
#    2017-04-30  ...  2020-03-31  2020-04-30  2020-05-31  2020-06-30  \
# ...

# %%
fl_filter=data['State']=="FL"
fl_df=data[fl_filter]
display(fl_df)
# Out:
#                RegionName RegionType State  \
# 7       Miami-Dade County     County    FL
# 17         Broward County     County    FL
# 27      Palm Beach County     County    FL
# 29    Hillsborough County     County    FL
# 34          Orange County     County    FL
# ...                   ...        ...   ...
# 2124       Calhoun County     County    FL
# 2229        Glades County     County    FL
# 2304      Franklin County     County    FL
# 2492     Lafayette County     County    FL
# 2537       Liberty County     County    FL
#
#                                       Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 7     Miami-Fort Lauderdale-West Palm Beach             12                 86
# 17    Miami-Fort Lauderdale-West Palm Beach             12                 11
# 27    Miami-Fort Lauderdale-West Palm Beach             12                 99
# 29          Tampa-St. Petersburg-Clearwater             12                 57
# ...

# %%
fl_percent_cols=fl_df[['RegionName','2017-03-31', '2020-02-29', '2020-03-31', '2020-12-31']]
miami_counties=["Miami-Dade County", "Broward County", "Palm Beach County", "Monroe County", "Collier County", "Lee County", "Hendry County", "Glades County", "Okeechobee County", "Martin County"]

pre_covid=[]
covid=[]

for each_county in miami_counties:
    fl_cnt_filter=fl_percent_cols['RegionName']==each_county  #just change county name and run cell
    
    mar2017=fl_percent_cols.loc[fl_cnt_filter,'2017-03-31']
    feb2020=fl_percent_cols.loc[fl_cnt_filter,'2020-02-29']
    mar2020=fl_percent_cols.loc[fl_cnt_filter,'2020-03-31']
    dec2020=fl_percent_cols.loc[fl_cnt_filter,'2020-12-31']
    
    pre_covid_annual=((((feb2020-mar2017)/feb2020)/3)*100).values[0]
    covid_annual=(((((dec2020-mar2017)/dec2020)/10)*10)*100).values[0]

    pre_covid.append(pre_covid_annual)
    covid.append(covid_annual)

display(pre_covid)
display(covid)
# Out:
# [3.858112824417793,
#  4.632071865443424,
#  3.677937565449753,
#  2.0843692348357563,
#  0.21855784919605756,
#  1.984270820747629,
#  6.110635641676481,
#  4.382965191653824,
#  5.125313504020487,
#  3.886453130631079]
# [16.2313339068787,
#  19.741048433162632,
#  16.300719791069497,
#  8.798975631733285,
#  6.789047642535747,
#  11.398382089153875,
#  21.442443005910498,
#  15.850545700167087,
#  21.58159433068809,
#  17.541442877706753]

# %%
plotdata = pd.DataFrame({
    "Pre Covid Value Change Per Year":[3.858112824417793,
 4.632071865443424,
 3.677937565449753,
 2.0843692348357563,
 0.21855784919605756,
 1.984270820747629,
 6.110635641676481,
 4.382965191653824,
 5.125313504020487,
 3.886453130631079],
    
    "During Covid Value Change":[16.2313339068787,
 19.741048433162632,
 16.300719791069497,
 8.798975631733285,
 6.789047642535747,
 11.398382089153875,
 21.442443005910498,
 15.850545700167087,
 21.58159433068809,
 17.541442877706753]
    
    }, 
    index=["Miami-Dade County", "Broward County", "Palm Beach County", "Monroe County", "Collier County", "Lee County", "Hendry County", "Glades County", "Okeechobee County", "Martin County"]

)

plotdata.plot(kind="bar")
plt.title("Miami Metro County Home Values Percent Change Over Time")
plt.xlabel("County Name")
plt.ylabel("Percent Change")
# Out:
# Text(0, 0.5, 'Percent Change')

# %% [markdown]
# # California

# %%
ca_filter=data['State']=="CA"
ca_df=data[ca_filter]
display(ca_df)
# Out:
#                   RegionName RegionType State  \
# 0         Los Angeles County     County    CA
# 4           San Diego County     County    CA
# 5              Orange County     County    CA
# 10          Riverside County     County    CA
# 11     San Bernardino County     County    CA
# 16        Santa Clara County     County    CA
# 21            Alameda County     County    CA
# 24         Sacramento County     County    CA
# 36       Contra Costa County     County    CA
# 45             Fresno County     County    CA
# 61               Kern County     County    CA
# 62            Ventura County     County    CA
# 65      San Francisco County     County    CA
# 81          San Mateo County     County    CA
# 86        San Joaquin County     County    CA
# 124        Stanislaus County     County    CA
# 136            Sonoma County     County    CA
# 145            Tulare County     County    CA
# 156     Santa Barbara County     County    CA
# ...

# %%
ca_percent_cols=ca_df[['RegionName','2017-03-31', '2020-02-29', '2020-03-31', '2020-12-31']]
la_counties=["Ventura County", "Kern County", "Santa Barbara County", "San Diego County", "Orange County", "Riverside County", "San Bernardino County"]

pre_covid=[]
covid=[]

for each_county in la_counties:
    ca_cnt_filter=ca_percent_cols['RegionName']==each_county  #just change county name and run cell
    
    mar2017=ca_percent_cols.loc[ca_cnt_filter,'2017-03-31']
    feb2020=ca_percent_cols.loc[ca_cnt_filter,'2020-02-29']
    mar2020=ca_percent_cols.loc[ca_cnt_filter,'2020-03-31']
    dec2020=ca_percent_cols.loc[ca_cnt_filter,'2020-12-31']
    
    pre_covid_annual=((((feb2020-mar2017)/feb2020)/3)*100).values[0]
    covid_annual=(((((dec2020-mar2017)/dec2020)/10)*10)*100).values[0]

    pre_covid.append(pre_covid_annual)
    covid.append(covid_annual)
    
display(pre_covid)
display(covid)
# Out:
# [2.6173834357597148,
#  4.1422928313942196,
#  3.1079968363137573,
#  4.086479988917577,
#  2.8368331840590106,
#  4.379312344175799,
#  4.731998368276424]
# [13.309310387312964,
#  20.94977183185313,
#  15.85391189318982,
#  20.984432672968257,
#  14.591302640913096,
#  20.564160599201912,
#  22.12213311850794]

# %%
plotdata = pd.DataFrame({
    "Pre Covid Value Change Per Year":[2.6173834357597148,
 4.1422928313942196,
 3.1079968363137573,
 4.086479988917577,
 2.8368331840590106,
 4.379312344175799,
 4.731998368276424],
    
    "During Covid Value Change":[13.309310387312964,
 20.94977183185313,
 15.85391189318982,
 20.984432672968257,
 14.591302640913096,
 20.564160599201912,
 22.12213311850794]
    
    }, 
    index=["Ventura County", "Kern County", "Santa Barbara County", "San Diego County", "Orange County", "Riverside County", "San Bernardino County"]
)

plotdata.plot(kind="bar")
plt.title("Los Angles Metro County Home Values Percent Change Over Time")
plt.xlabel("County Name")
plt.ylabel("Percent Change")
# Out:
# Text(0, 0.5, 'Percent Change')
