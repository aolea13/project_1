# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "data/zhvi_data.csv"
home_values_df=pd.read_csv(file_path)

home_values_df.head()
# Out:
#            RegionName RegionType State                             Metro  \
# 0  Los Angeles County     County    CA    Los Angeles-Long Beach-Anaheim
# 1         Cook County     County    IL          Chicago-Naperville-Elgin
# 2       Harris County     County    TX  Houston-The Woodlands-Sugar Land
# 3     Maricopa County     County    AZ           Phoenix-Mesa-Scottsdale
# 4    San Diego County     County    CA                San Diego-Carlsbad
#
#    StateCodeFIPS  MunicipalCodeFIPS  2017-01-31  2017-02-28  2017-03-31  \
# 0              6                 37    567167.0    570020.0    573344.0
# 1             17                 31    235165.0    235814.0    237493.0
# 2             48                201    177989.0    178366.0    178869.0
# 3              4                 13    242028.0    243189.0    244568.0
# 4              6                 73    528758.0    531624.0    536251.0
#
#    2017-04-30  ...  2020-03-31  2020-04-30  2020-05-31  2020-06-30  \
# ...

# %%
# sort by states of interest: CA, TX, FL and maybe create new dataframes 
ca_filter=home_values_df['State']=="CA"
ca_df=home_values_df[ca_filter]
ca_df.head()
# Out:
#                RegionName RegionType State                             Metro  \
# 0      Los Angeles County     County    CA    Los Angeles-Long Beach-Anaheim
# 4        San Diego County     County    CA                San Diego-Carlsbad
# 5           Orange County     County    CA    Los Angeles-Long Beach-Anaheim
# 10       Riverside County     County    CA  Riverside-San Bernardino-Ontario
# 11  San Bernardino County     County    CA  Riverside-San Bernardino-Ontario
#
#     StateCodeFIPS  MunicipalCodeFIPS  2017-01-31  2017-02-28  2017-03-31  \
# 0               6                 37    567167.0    570020.0    573344.0
# 4               6                 73    528758.0    531624.0    536251.0
# 5               6                 59    681126.0    683169.0    687464.0
# 10              6                 65    347153.0    347680.0    349559.0
# 11              6                 71    314366.0    317104.0    319015.0
#
# ...

# %%
ca_df.describe()
# Out:
#        StateCodeFIPS  MunicipalCodeFIPS    2017-01-31    2017-02-28  \
# count           58.0          58.000000  5.800000e+01  5.800000e+01
# mean             6.0          58.000000  4.139597e+05  4.161286e+05
# std              0.0          33.773757  2.492429e+05  2.507464e+05
# min              6.0           1.000000  1.242460e+05  1.247810e+05
# 25%              6.0          29.500000  2.319052e+05  2.333940e+05
# 50%              6.0          58.000000  3.169375e+05  3.198080e+05
# 75%              6.0          86.500000  5.565882e+05  5.605740e+05
# max              6.0         115.000000  1.217339e+06  1.213460e+06
#
#          2017-03-31    2017-04-30    2017-05-31    2017-06-30    2017-07-31  \
# count  5.800000e+01  5.800000e+01  5.800000e+01  5.800000e+01  5.800000e+01
# mean   4.181369e+05  4.201159e+05  4.223700e+05  4.247686e+05  4.271683e+05
# std    2.515927e+05  2.528771e+05  2.544376e+05  2.560433e+05  2.582795e+05
# ...

# %%
price_columns= ['2017-01-31', '2017-02-28', '2017-03-31',
       '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
       '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31',
       '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30',
       '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30',
       '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
       '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30',
       '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29',
       '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30', '2020-07-31',
       '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31']



# len(la_price_over_time.iloc[0])
# la_df.loc[:, '2017-01-31':'2020-12-31']

# %%
# Create a line plot showing ZHVI for LA County
la_cnt_filter=home_values_df['RegionName']=="Los Angeles County"

la_price_over_time=ca_df.loc[la_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,la_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Los Angeles County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing ZHVI in San Bernardino County

# go through to find row where RegionName=San Bernardino County, and pull all the date values then graph. 
sanbern_cnt_filter=home_values_df['RegionName']=="San Bernardino County"

sanbern_price_over_time=ca_df.loc[sanbern_cnt_filter, price_columns]

# display(sanbern_price_over_time.iloc[0])

plt.figure(figsize=(12,8))
plt.plot(price_columns,sanbern_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("San Bernardino County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing ZHVI in Riverside County


# go through to find row where RegionName=San Bernardino County, and pull all the date values then graph. 
riverside_cnt_filter=home_values_df['RegionName']=="Riverside County"

riverside_price_over_time=ca_df.loc[riverside_cnt_filter, price_columns]

# display(sanbern_price_over_time.iloc[0])

plt.figure(figsize=(12,8))
plt.plot(price_columns,riverside_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Riverside County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
#Create stacked plot showing ZHVI of all three counties

plt.figure(figsize=(12,8))
plt.plot(price_columns,riverside_price_over_time.iloc[0], label="Riverside County")
plt.plot(price_columns,sanbern_price_over_time.iloc[0], label="San Bernardino County")
plt.plot(price_columns,la_price_over_time.iloc[0], label="Los Angeles County")
plt.legend()
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("California County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
tx_filter=home_values_df['State']=="TX"
tx_df=home_values_df[tx_filter]
tx_df.head()
# Out:
#         RegionName RegionType State                             Metro  \
# 2    Harris County     County    TX  Houston-The Woodlands-Sugar Land
# 8    Dallas County     County    TX       Dallas-Fort Worth-Arlington
# 15  Tarrant County     County    TX       Dallas-Fort Worth-Arlington
# 18    Bexar County     County    TX         San Antonio-New Braunfels
# 38   Travis County     County    TX                 Austin-Round Rock
#
#     StateCodeFIPS  MunicipalCodeFIPS  2017-01-31  2017-02-28  2017-03-31  \
# 2              48                201    177989.0    178366.0    178869.0
# 8              48                113    174377.0    175932.0    177609.0
# 15             48                439    185472.0    187321.0    188536.0
# 18             48                 29    167718.0    169434.0    170465.0
# 38             48                453    332548.0    333264.0    334760.0
#
#     2017-04-30  ...  2020-03-31  2020-04-30  2020-05-31  2020-06-30  \
# ...

# %%
# Create a line plot showing ZHVI for Harris County
harris_filter=home_values_df['RegionName']=="Harris County"

harris_price_over_time=home_values_df.loc[harris_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,harris_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Harris County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing ZHVI for Dallas County
dallas_filter=home_values_df['RegionName']=="Dallas County"

dallas_price_over_time=home_values_df.loc[dallas_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,dallas_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Dallas County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing ZHVI for Harris County
tarrant_filter=home_values_df['RegionName']=="Tarrant County"

tarrant_price_over_time=home_values_df.loc[tarrant_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,tarrant_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Tarrant County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
#Create stacked plot showing ZHVI of all three TX counties

plt.figure(figsize=(12,8))
plt.plot(price_columns,harris_price_over_time.iloc[0], label="Harris County")
plt.plot(price_columns,dallas_price_over_time.iloc[0], label="Dallas County")
plt.plot(price_columns,tarrant_price_over_time.iloc[0], label="Tarrant County")
plt.legend()
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Texas County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
fl_filter=home_values_df['State']=="FL"
fl_df=home_values_df[fl_filter]
fl_df.head()
# Out:
#              RegionName RegionType State  \
# 7     Miami-Dade County     County    FL
# 17       Broward County     County    FL
# 27    Palm Beach County     County    FL
# 29  Hillsborough County     County    FL
# 34        Orange County     County    FL
#
#                                     Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 7   Miami-Fort Lauderdale-West Palm Beach             12                 86
# 17  Miami-Fort Lauderdale-West Palm Beach             12                 11
# 27  Miami-Fort Lauderdale-West Palm Beach             12                 99
# 29        Tampa-St. Petersburg-Clearwater             12                 57
# 34              Orlando-Kissimmee-Sanford             12                 95
#
#     2017-01-31  2017-02-28  2017-03-31  2017-04-30  ...  2020-03-31  \
# 7     280519.0    282088.0    283345.0    284333.0  ...    321646.0
# 17    238467.0    239408.0    240264.0    242297.0  ...    280189.0
# ...

# %%
# Create a line plot showing ZHVI for Harris County
miami_filter=home_values_df['RegionName']=="Miami-Dade County"

miami_price_over_time=home_values_df.loc[miami_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,miami_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Miami-Dade County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing ZHVI for Broward County
broward_filter=home_values_df['RegionName']=="Broward County"

broward_price_over_time=home_values_df.loc[harris_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,broward_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Broward County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing ZHVI for Palm Beach County
palmbeach_filter=home_values_df['RegionName']=="Palm Beach County"

palmbeach_price_over_time=home_values_df.loc[palmbeach_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,palmbeach_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Palm Beach County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
#Create stacked plot showing ZHVI of all three FL counties

plt.figure(figsize=(12,8))
plt.plot(price_columns,miami_price_over_time.iloc[0], label="Miami-Dade County")
plt.plot(price_columns,broward_price_over_time.iloc[0], label="Broward County")
plt.plot(price_columns,palmbeach_price_over_time.iloc[0], label="Palm Beach County")
plt.legend()
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Florida County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()
