# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = "data/Metro_invt_fs_uc_sfrcondo_smoothed_month.csv"

sales_inventory_df=pd.read_csv(file_path)

sales_inventory_df.head()
# Out:
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
#
#   StateName  2018-01-31  2018-02-28  2018-03-31  2018-04-30  2018-05-31  ...  \
# 0       NaN   1428882.0   1386415.0   1443722.0   1530952.0   1632853.0  ...
# 1        NY     68777.0     68337.0     72854.0     79773.0     85784.0  ...
# 2        CA     20160.0     19980.0     21934.0     23855.0     25827.0  ...
# 3        IL     37451.0     36002.0     39176.0     43136.0     47066.0  ...
# 4        TX     24288.0     23207.0     24351.0     26757.0     29551.0  ...
#
#    2020-03-31  2020-04-30  2020-05-31  2020-06-30  2020-07-31  2020-08-31  \
# ...

# %%
display(sales_inventory_df)
# Out:
#     RegionID  SizeRank                          RegionName RegionType  \
# 0     102001         0                       United States    Country
# 1     394913         1                        New York, NY        Msa
# 2     753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3     394463         3                         Chicago, IL        Msa
# 4     394514         4               Dallas-Fort Worth, TX        Msa
# ..       ...       ...                                 ...        ...
# 92    394711        92                         Jackson, MS        Msa
# 93    394352        94                         Augusta, GA        Msa
# 94    394666        96                      Harrisburg, PA        Msa
# 95    395006       100                           Provo, UT        Msa
# 96    394602       159                    Fort Collins, CO        Msa
#
#    StateName  2018-01-31  2018-02-28  2018-03-31  2018-04-30  2018-05-31  ...  \
# ...

# %%
sales_inventory_df.count()
# Out:
# RegionID      97
# SizeRank      97
# RegionName    97
# RegionType    97
# StateName     96
# 2018-01-31    97
# 2018-02-28    97
# 2018-03-31    97
# 2018-04-30    97
# 2018-05-31    97
# 2018-06-30    97
# 2018-07-31    97
# 2018-08-31    97
# 2018-09-30    97
# 2018-10-31    97
# 2018-11-30    97
# 2018-12-31    97
# 2019-01-31    97
# 2019-02-28    97
# 2019-03-31    97
# 2019-04-30    97
# 2019-05-31    97
# 2019-06-30    97
# 2019-07-31    97
# 2019-08-31    97
# 2019-09-30    97
# 2019-10-31    97
# 2019-11-30    97
# 2019-12-31    97
# 2020-01-31    97
# 2020-02-29    97
# 2020-03-31    97
# 2020-04-30    97
# 2020-05-31    97
# 2020-06-30    97
# 2020-07-31    97
# 2020-08-31    94
# 2020-09-30    93
# 2020-10-31    93
# 2020-11-30    94
# 2020-12-31    97
# dtype: int64

# %%
ca_filter=sales_inventory_df['StateName']=="CA"
display(sales_inventory_df[ca_filter])
# Out:
#     RegionID  SizeRank                          RegionName RegionType  \
# 2     753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 11    395057        11                   San Francisco, CA        Msa
# 13    395025        13                       Riverside, CA        Msa
# 17    395056        17                       San Diego, CA        Msa
# 25    395045        25                      Sacramento, CA        Msa
# 34    395059        34                        San Jose, CA        Msa
# 56    394619        56                          Fresno, CA        Msa
# 63    394357        63                     Bakersfield, CA        Msa
# 66    394952        66                         Ventura, CA        Msa
# 77    395134        77                        Stockton, CA        Msa
#
#    StateName  2018-01-31  2018-02-28  2018-03-31  2018-04-30  2018-05-31  ...  \
# 2         CA     20160.0     19980.0     21934.0     23855.0     25827.0  ...
# ...

# %%
sales_inventory_df.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31',
#        '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31',
#        '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31',
#        '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#        '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31',
#        '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30',
#        '2020-07-31', '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30',
#        '2020-12-31'],
#       dtype='object')

# %%
data_columns= ['2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31',
       '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31',
       '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31',
       '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
       '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31',
       '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30',
       '2020-07-31', '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30',
       '2020-12-31']

# %%
# Create a line plot showing For Sale inventory for Riverside Metro Area
riverside_filter=sales_inventory_df['RegionName']=="Riverside, CA"

riverside_inventory_over_time=sales_inventory_df.loc[riverside_filter, data_columns]

plt.figure(figsize=(12,8))
plt.plot(data_columns,riverside_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("Riverside Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing For Sale inventory for LA County
la_filter=sales_inventory_df['RegionName']=="Los Angeles-Long Beach-Anaheim, CA"

la_inventory_over_time=sales_inventory_df.loc[la_filter, data_columns]

plt.figure(figsize=(12,8))
plt.plot(data_columns,la_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("LA Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing For Sale inventory for Riverside Metro Area
ventura_filter=sales_inventory_df['RegionName']=="Ventura, CA"

ventura_inventory_over_time=sales_inventory_df.loc[ventura_filter, data_columns]

# la_filter=sales_inventory_df['RegionName']=="Los Angeles-Long Beach-Anaheim, CA"

# la_inventory_over_time=sales_inventory_df.loc[la_filter, data_columns]



plt.figure(figsize=(12,8))
plt.plot(data_columns,ventura_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("Ventura Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# do the same for each primary county in CA and the surrounding counties (same as state analysis)

# Create a line plot showing For Sale inventory for Riverside Metro Area
sf_filter=sales_inventory_df['RegionName']=="San Francisco, CA"

sf_inventory_over_time=sales_inventory_df.loc[sf_filter, data_columns]

plt.figure(figsize=(12,8))
plt.plot(data_columns,sf_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("San Francisco Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing For Sale inventory for Riverside Metro Area
sandiego_filter=sales_inventory_df['RegionName']=="San Diego, CA"

sandiego_inventory_over_time=sales_inventory_df.loc[sandiego_filter, data_columns]

plt.figure(figsize=(12,8))
plt.plot(data_columns,sandiego_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("San Diego Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing For Sale inventory for Riverside Metro Area
sacramento_filter=sales_inventory_df['RegionName']=="Sacramento, CA"

sacramento_inventory_over_time=sales_inventory_df.loc[sacramento_filter, data_columns]

plt.figure(figsize=(12,8))
plt.plot(data_columns,sacramento_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("Sacramento Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing For Sale inventory for Riverside Metro Area
sj_filter=sales_inventory_df['RegionName']=="San Jose, CA"

sj_inventory_over_time=sales_inventory_df.loc[sj_filter, data_columns]

plt.figure(figsize=(12,8))
plt.plot(data_columns,sj_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("San Jose Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing For Sale inventory for Riverside Metro Area
fresno_filter=sales_inventory_df['RegionName']=="Fresno, CA"

fresno_inventory_over_time=sales_inventory_df.loc[fresno_filter, data_columns]

plt.figure(figsize=(12,8))
plt.plot(data_columns,fresno_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("Fresno Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing For Sale inventory for Riverside Metro Area
bake_filter=sales_inventory_df['RegionName']=="Bakersfield, CA"

bake_inventory_over_time=sales_inventory_df.loc[bake_filter, data_columns]

plt.figure(figsize=(12,8))
plt.plot(data_columns,bake_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("Bakersfield, CA Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing For Sale inventory for Riverside Metro Area
ventura_filter=sales_inventory_df['RegionName']=="Ventura, CA"

ventura_inventory_over_time=sales_inventory_df.loc[ventura_filter, data_columns]

plt.figure(figsize=(12,8))
plt.plot(data_columns,ventura_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("Ventura, CA Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()

# %%
# Create a line plot showing For Sale inventory for Riverside Metro Area
stockton_filter=sales_inventory_df['RegionName']=="Stockton, CA"

stockton_inventory_over_time=sales_inventory_df.loc[stockton_filter, data_columns]

plt.figure(figsize=(12,8))
plt.plot(data_columns,stockton_inventory_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("For Sale Inventory")
plt.title("Stockton, CA Regional Sales Inventory 2018-2020")
plt.xticks(fontsize=8,rotation=90)

plt.show()
