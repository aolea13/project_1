# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# <h1><font size="4">Investigate the effects of COVID-19 on the migration patterns of the US population and whether or not this has had any effect on the real estate markets in surrounding areas.</font></h2>
# <h3><font size="4">What outcome do we expect?</font></h3>
# <br>
#   <li><font size="3">Cities with higher positive COVID-19 cases have greater movement to suburbs/smaller cities.</font></li>
#     <li><font size="3">Housing prices to increase to more suburban areas.</font></li>
